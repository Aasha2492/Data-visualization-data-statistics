# %%
# Import libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("titanic_dataset.csv")
df.head()
# Out:
#    PassengerId                   Name     Sex   Age  Pclass   Fare  SibSp  \
# 0            1        Mr. Owen Harris    male  22.0       3   7.25      1
# 1            2      Mrs. John Bradley  female  38.0       1  71.28      1
# 2            3  Miss. Laina Heikkinen  female  26.0       3   7.92      0
# 3            4     Mrs. Jacques Heath  female  35.0       1  53.10      1
# 4            5      Mr. William Allen    male  35.0       3   8.05      0
#
#    Parch Embarked  Survived
# 0      0        S         0
# 1      0        C         1
# 2      0        S         1
# 3      0        S         1
# 4      0        S         0

# %%
survival_counts = df['Survived'].value_counts()

plt.figure()
survival_counts.plot(kind='bar')
plt.title('Survived vs Not Survived')
plt.xlabel('Survival (0 = Not Survived, 1 = Survived)')
plt.ylabel('Number of Passengers')
plt.show()

# %%
plt.figure()
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.title('Fare Distribution by Passenger Class')
plt.show()

# %%
mean_age = df['Age'].mean()
median_age = df['Age'].median()

print('Mean Age:', mean_age)
print('Median Age:', median_age)
# Out:
# Mean Age: 27.272727272727273
# Median Age: 27.5

# %%
step 4

Most passengers did not survive the Titanic disaster. First-class passengers paid higher fares compared to other classes, and the age statistics show variation in passenger ages.
